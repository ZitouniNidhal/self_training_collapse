# %% [markdown]
# # Repository Overview
# This notebook provides a quick introduction to the `self_training_collapse` repository, its structure, and the available analysis workflows.

# %%
import os
from pathlib import Path

repo_root = Path(os.getcwd())
print('Repository root:', repo_root)
# Out:
# Repository root: c:\Users\nidha\Desktop\github reposistory\self_training_collapse\self_training_collapse\notebooks

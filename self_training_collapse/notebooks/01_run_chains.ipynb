# %% [markdown]
# # Run Chain Examples
# This notebook shows how to execute the repository's chain workflows from Python.

# %%
from self_training_collapse.scripts import run_care_chain

print('Imported chain runner successfully')
